# %%
from pathlib import Path

import pandas as pd

cefr_words = pd.concat(
    [
        (
            pd.read_csv(i)
            .rename(columns={0: "word"})
            .assign(level=i.stem)
            .pipe(lambda x: x[x["word"].str.isalpha()])
        )
        for i in Path("cefr_words").glob("*.csv")
    ]
)
print(cefr_words)

for i in Path("book_vocab").glob("*.csv"):
    df = pd.read_csv(i)
    df = pd.merge(df, cefr_words, on="word", how="left").loc[:, ["word", "level"]]
    df.to_csv(i.parent.parent / "books_vocab_cefr" / i.name, index=False)

# %%
for i in Path("books_vocab_cefr").glob("*.csv"):
    df = pd.read_csv(i)
    df = df.fillna(value="BEYOND")
    df.to_csv(i, index=False)

# %%
from pathlib import Path
import pandas as pd
from reading_path_builder import LayeredCEFRBookSelector

books_vocab = {
    book_name.stem: set(pd.read_csv(book_name)["word"])
    for book_name in Path("book_vocab").glob("*.csv")
    # if not any(
    #     x in book_name.stem for x in ["书虫", "译林", "大英百科", "双语", "精讲版"]
    # )
}
vocab_levels = pd.concat(
    [
        (
            pd.read_csv(i, header=None)
            .rename(columns={0: "word"})
            .assign(level=i.stem)
            .pipe(lambda x: x[x["word"].str.isalpha()])
        )
        for i in Path("cefr_words").glob("*.csv")
    ]
)
vocab_levels = {i.word: i.level for i in vocab_levels.itertuples()}

book_selector = LayeredCEFRBookSelector(
    books_vocab=books_vocab, vocab_levels=vocab_levels
)
# Out:
# 📚 学习词表分层统计（来自 vocab_levels）:
#   A1: 801词
#   A2: 733词
#   B1: 800词
#   B2: 1358词
#   C1: 1300词

# %%
# 获取多种路径方案

print(
    book_selector.create_progressive_reading_path(
        max_books_per_level={"A1": 7, "A2": 6, "B1": 5, "B2": 3, "C1": 2},
        target_coverage_per_level={
            "A1": 0.95,
            "A2": 0.95,
            "B1": 0.95,
            "B2": 0.95,
            "C1": 0.95,
        },
        max_unknown_ratio=0.4,
        min_relevant_ratio=0.6,
        min_target_level_words=100,
    )
)
# Out:
# === 选择 A1 等级书籍 ===
#   A1等级候选书籍: 6本
# 目标词汇: 801, 已覆盖: 0, 待覆盖: 801
#   选择: lorkq-小公主 | 有声书虫（1级）
#   新增A1词汇: 198
#   当前覆盖率: 24.7%
#   选择: btsbyz-爱情与金钱 | 有声书虫（1级）
#   新增A1词汇: 53
#   当前覆盖率: 31.3%
#   选择: jvvhu-风中奇缘 | 有声书虫（2级）
#   新增A1词汇: 22
#   当前覆盖率: 34.1%
#   选择: bbagn-潘德尔的巫师 | 有声书虫（1级）
#   新增A1词汇: 10
#   当前覆盖率: 35.3%
#   选择: bntzc-阿拉丁和神灯 | 有声书虫（1级）
#   新增A1词汇: 4
#   当前覆盖率: 35.8%
#   选择: gjxdl-猴爪 | 有声书虫（1级）
#   新增A1词汇: 2
#   当前覆盖率: 36.1%
# 完成 A1 后累积覆盖率:
#   A1: 36.1%
#   A2: 14.5%
#   B1: 6.8%
#   B2: 2.4%
#   C1: 0.8%
#
# === 选择 A2 等级书籍 ===
#   A2等级候选书籍: 17本
# 目标词汇: 733, 已覆盖: 106, 待覆盖: 627
#   选择: bsvzaa-三十九级台阶 | 有声书虫（4级）
#   新增A2词汇: 164
#   当前覆盖率: 22.4%
#   选择: efwol-巴斯克维尔猎犬 | 有声书虫（4级）
#   新增A2词汇: 52
#   当前覆盖率: 29.5%
#   选择: xodqi-三怪客泛舟记 | 有声书虫（4级）
#   新增A2词汇: 18
#   当前覆盖率: 31.9%
#   选择: ivqus-小妇人 | 有声书虫（4级）
#   新增A2词汇: 13
#   当前覆盖率: 33.7%
#   选择: cktrg-勃朗特一家的故事 | 有声书虫（3级）
#   新增A2词汇: 8
#   当前覆盖率: 34.8%
#   选择: rxrhp-一个国王的爱情故事 | 有声书虫（2级）
#   新增A2词汇: 6
#   当前覆盖率: 35.6%
# 完成 A2 后累积覆盖率:
#   A1: 57.7%
#   A2: 50.1%
#   B1: 31.5%
#   B2: 11.8%
#   C1: 3.1%
#
# === 选择 B1 等级书籍 ===
#   B1等级候选书籍: 18本
# 目标词汇: 800, 已覆盖: 252, 待覆盖: 548
#   选择: shzmq-简·爱 | 有声书虫（6级）
#   新增B1词汇: 123
#   当前覆盖率: 15.4%
#   选择: pejdp-白衣女人 | 有声书虫（6级）
#   新增B1词汇: 55
#   当前覆盖率: 22.2%
#   选择: dqgsa-雾都孤儿 | 有声书虫（6级）
#   新增B1词汇: 32
#   当前覆盖率: 26.2%
#   选择: bbzpii-格列佛游记 | 有声书虫（4级）
#   新增B1词汇: 11
#   当前覆盖率: 27.6%
#   选择: asyse-远大前程 | 有声书虫（5级）
#   新增B1词汇: 9
#   当前覆盖率: 28.7%
# 完成 B1 后累积覆盖率:
#   A1: 64.4%
#   A2: 68.2%
#   B1: 60.2%
#   B2: 32.5%
#   C1: 11.0%
#
# === 选择 B2 等级书籍 ===
#   B2等级候选书籍: 112本
# 目标词汇: 1358, 已覆盖: 442, 待覆盖: 916
#   选择: hnzbp-太空探索｜大英百科
#   新增B2词汇: 267
#   当前覆盖率: 19.7%
#   选择: blnue-天气及气候学界的先驱｜大英百科
#   新增B2词汇: 113
#   当前覆盖率: 28.0%
#   选择: mlpvz-驶过时间海洋的小舟
#   新增B2词汇: 77
#   当前覆盖率: 33.7%
# 完成 B2 后累积覆盖率:
#   A1: 69.8%
#   A2: 82.3%
#   B1: 81.9%
#   B2: 66.2%
#   C1: 39.8%
#
# === 选择 C1 等级书籍 ===
#   C1等级候选书籍: 84本
# 目标词汇: 1300, 已覆盖: 517, 待覆盖: 783
#   选择: mmnog-爱尔兰｜大英百科
#   新增C1词汇: 308
#   当前覆盖率: 23.7%
#   选择: svbtq-游戏：从Atari到Xbox｜大英百科
#   新增C1词汇: 106
#   当前覆盖率: 31.8%
# 完成 C1 后累积覆盖率:
#   A1: 72.3%
#   A2: 87.2%
#   B1: 90.1%
#   B2: 85.1%
#   C1: 71.6%
）', 'xodqi-三怪客泛舟记 | 有声书虫（4级）', 'ivqus-小妇人 | 有声书虫（4级）', 'cktrg-勃朗特一家的故事 | 有声书虫（3级）', 'rxrhp-一个国王的爱情故事 | 有声书虫（2级）'], 'coverage': 0.35607094133697137, 'new_words_covered': {'fresh', 'crime', 'safe', 'avoid', 'impossible', 'dry', 'heart', 'unfortunately', 'photograph', 'effect', 'report', 'receive', 'condition', 'fishing', 'pub', 'disagree', 'silver', 'belong', 'wooden', 'biscuit', 'headache', 'ride', 'coast', 'couple', 'illness', 'straight', 'plant', 'notice', 'shut', 'use', 'camp', 'owner', 'oil', 'knee', 'behave', 'discover', 'moon', 'flat', 'surprising', 'cross', 'neck', 'arrange', 'uniform', 'wash', 'metal', 'danger', 'bridge', 'attack', 'engine', 'helpful', 'mind', 'thinking', 'cloud', 'lake', 'extremely', 'wild', 'simple', 'bit', 'jewellery', 'weak', 'certainly', 'regular', 'single', 'direction', 'habit', 'adult', 'badly', 'castle', 'likely', 'laughter', 'soft', 'drawing', 'hide', 'soap', ' ...

# %%
path = book_selector.create_progressive_reading_path(
    max_books_per_level={"A1": 3, "A2": 3, "B1": 4, "B2": 3, "C1": 3},
    target_coverage_per_level={"A1": 0.85, "A2": 0.9, "B1": 0.9, "B2": 0.9, "C1": 0.9},
    max_unknown_ratio=0.5,
    min_relevant_ratio=0.5,
    min_target_level_words=50,
)

# 输出路径
book_selector.print_reading_path(path, "推荐路径")

# %%
# 获取多种路径方案
paths = book_selector.get_alternative_paths()

# 展示所有路径
for path_name, path_result in paths:
    book_selector.print_reading_path(path_result, path_name)
# Out:
# === 选择 A1 等级书籍 ===
#   A1等级候选书籍: 7本
# 目标词汇: 801, 已覆盖: 0, 待覆盖: 801
#   选择: lorkq-小公主 | 有声书虫（1级）
#   新增A1词汇: 198
#   当前覆盖率: 24.7%
#   选择: btsbyz-爱情与金钱 | 有声书虫（1级）
#   新增A1词汇: 53
#   当前覆盖率: 31.3%
#   选择: jvvhu-风中奇缘 | 有声书虫（2级）
#   新增A1词汇: 22
#   当前覆盖率: 34.1%
#   选择: bbagn-潘德尔的巫师 | 有声书虫（1级）
#   新增A1词汇: 10
#   当前覆盖率: 35.3%
# 完成 A1 后累积覆盖率:
#   A1: 35.3%
#   A2: 12.7%
#   B1: 5.5%
#   B2: 1.8%
#   C1: 0.5%
#
# === 选择 A2 等级书籍 ===
#   A2等级候选书籍: 16本
# 目标词汇: 733, 已覆盖: 93, 待覆盖: 640
#   选择: bbvlrq-弗兰肯斯坦 | 有声书虫（3级）
#   新增A2词汇: 88
#   当前覆盖率: 12.0%
#   选择: dlmqa-华特·迪士尼传｜大英百科
#   新增A2词汇: 51
#   当前覆盖率: 19.0%
#   选择: bvdvdp-乔布斯传｜大英百科
#   新增A2词汇: 35
#   当前覆盖率: 23.7%
#   选择: cktrg-勃朗特一家的故事 | 有声书虫（3级）
#   新增A2词汇: 27
#   当前覆盖率: 27.4%
# 完成 A2 后累积覆盖率:
#   A1: 55.3%
#   A2: 40.1%
#   B1: 20.8%
#   B2: 8.5%
#   C1: 2.3%
#
# === 选择 B1 等级书籍 ===
#   B1等级候选书籍: 2本
# 警告: B1 没有找到合适的候选书籍
# 完成 B1 后累积覆盖率:
#   A1: 55.3%
#   A2: 40.1%
#   B1: 20.8%
#   B2: 8.5%
#   C1: 2.3%
#
# === 选择 B2 等级书籍 ===
#   B2等级候选书籍: 0本
# 警告: B2 没有找到合适的候选书籍
# 完成 B2 后累积覆盖率:
#   A1: 55.3%
#   A2: 40.1%
#   B1: 20.8%
#   B2: 8.5%
#   C1: 2.3%
#
# === 选择 C1 等级书籍 ===
#   C1等级候选书籍: 0本
# 警告: C1 没有找到合适的候选书籍
# 完成 C1 后累积覆盖率:
#   A1: 55.3%
#   A2: 40.1%
#   B1: 20.8%
#   B2: 8.5%
#   C1: 2.3%
#
# === 选择 A1 等级书籍 ===
#   A1等级候选书籍: 31本
# 目标词汇: 801, 已覆盖: 0, 待覆盖: 801
#   选择: xodqi-三怪客泛舟记 | 有声书虫（4级）
#   新增A1词汇: 329
#   当前覆盖率: 41.1%
#   选择: bvdvdp-乔布斯传｜大英百科
#   新增A1词汇: 54
#   当前覆盖率: 47.8%
#   选择: cktrg-勃朗特一家的故事 | 有声书虫（3级）
#   新增A1词汇: 39
#   当前覆盖率: 52.7%
# 完成 A1 后累积覆盖率:
#   A1: 52.7%
#   A2: 36.7%
#   B1: 19.6%
#   B2: 7.5%
#   C1: 1.5%
#
# === 选择 A2 等级书籍 ===
#   A2等级候选书籍: 40本
# 目标词汇: 733, 已覆盖: 269, 待覆盖: 464
#   选择: asyse-远大前程 | 有声书虫（5级）
#   新增A2词汇: 100
#   当前覆盖率: 13.6%
#   选择: bsvzaa-三十九级台阶 | 有声书虫（4级）
#   新增A2词汇: 40
#   当前覆盖率: 19.1%
#   选择: bbzpii-格列佛游记 | 有声书虫（4级）
#   新增A2词汇: 17
#   当前覆盖率: 21.4%
# 完成 A2 后累积覆盖率:
#   A1: 61.9%
#   A2: 58.1%
#   B1: 43.9%
#   B2: 17.7%
#   C1: 4.8%
#
# === 选择 B1 等级书籍 ===
#   B1等级候选书籍: 27本
# 目标词汇: 800, 已覆盖: 351, 待覆盖: 449
#   选择: efwol-巴斯克维尔猎犬 | 有声书虫（4级）
#   新增B1词汇: 13
#   当前覆盖率: 1.6%
#   选择: dlmqa-华特·迪士尼传｜大英百科
#   新增B1词汇: 18
#   当前覆盖率: 3.9%
#   选择: grsai-黑骏马 | 有声书虫（4级）
#   新增B1词汇: 10
#   当前覆盖率: 5.1%
#   选择: utuix-金银岛 | 有声书虫（4级）
#   新增B1词汇: 7
#   当前覆盖率: 6.0%
# 完成 B1 后累积覆盖率:
#   A1: 63.9%
#   A2: 61.9%
#   B1: 49.9%
#   B2: 22.0%
#   C1: 6.5%
#
# === 选择 B2 等级书籍 ===
#   B2等级候选书籍: 21本
# 目标词汇: 1358, 已覆盖: 299, 待覆盖: 1059
#   选择: hlzpn-双城记 | 有声书虫（4级）
#   新增B2词汇: 3
#   当前覆盖率: 0.2%
#   选择: qdetg-神秘及幻想故事集 | 有声书虫（3级）
#   新增B2词汇: 4
#   当前覆盖率: 0.5%
#   选择: ivqus-小妇人 | 有声书虫（4级）
#   新增B2词汇: 2
#   当前覆盖率: 0.7%
# 完成 B2 后累积覆盖率:
#   A1: 64.9%
#   A2: 63.3%
#   B1: 51.2%
#   B2: 22.7%
#   C1: 7.1%
#
# === 选择 C1 等级书籍 ===
#   C1等级候选书籍: 1本
# 警告: C1 没有找到合适的候选书籍
# 完成 C1 后累积覆盖率:
#   A1: 64.9%
#   A2: 63.3%
#   B1: 51.2%
#   B2: 22.7%
#   C1: 7.1%
#
# === 选择 A1 等级书籍 ===
#   A1等级候选书籍: 43本
# 目标词汇: 801, 已覆盖: 0, 待覆盖: 801
#   选择: bsvzaa-三十九级台阶 | 有声书虫（4级）
#   新增A1词汇: 334
#   当前覆盖率: 41.7%
#   选择: ivqus-小妇人 | 有声书虫（4级）
#   新增A1词汇: 71
#   当前覆盖率: 50.6%
# 完成 A1 后累积覆盖率:
#   A1: 50.6%
#   A2: 41.5%
#   B1: 21.5%
#   B2: 7.7%
#   C1: 1.5%
#
# === 选择 A2 等级书籍 ===
#   A2等级候选书籍: 96本
# 目标词汇: 733, 已覆盖: 304, 待覆盖: 429
#   选择: edgbg-谁发明了电脑？｜大英百科
#   新增A2词汇: 120
#   当前覆盖率: 16.4%
#   选择: pejdp-白衣女人 | 有声书虫（6级）
#   新增A2词汇: 69
#   当前覆盖率: 25.8%
#   选择: bbzpii-格列佛游记 | 有声书虫（4级）
#   新增A2词汇: 23
#   当前覆盖率: 28.9%
# 完成 A2 后累积覆盖率:
#   A1: 60.5%
#   A2: 70.4%
#   B1: 57.5%
#   B2: 35.0%
#   C1: 12.7%
#
# === 选择 B1 等级书籍 ===
#   B1等级候选书籍: 98本
# 目标词汇: 800, 已覆盖: 460, 待覆盖: 340
#   选择: vvkqa-为什么雨林正遭破坏？｜大英百科
#   新增B1词汇: 64
#   当前覆盖率: 8.0%
#   选择: shzmq-简·爱 | 有声书虫（6级）
#   新增B1词汇: 33
#   当前覆盖率: 12.1%
#   选择: jxxue-我们的能量快用完了吗？｜大英百科
#   新增B1词汇: 32
#   当前覆盖率: 16.1%
#   选择: xodqi-三怪客泛舟记 | 有声书虫（4级）
#   新增B1词汇: 9
#   当前覆盖率: 17.2%
# 完成 B1 后累积覆盖率:
#   A1: 66.0%
#   A2: 77.9%
#   B1: 74.8%
#   B2: 54.1%
#   C1: 25.5%
#
# === 选择 B2 等级书籍 ===
#   B2等级候选书籍: 96本
# 目标词汇: 1358, 已覆盖: 734, 待覆盖: 624
#   选择: bqtdvg-统计与概率｜大英百科
#   新增B2词汇: 80
#   当前覆盖率: 5.9%
#   选择: fbvjq-篮球及最伟大的篮球运动员们｜大英百科
#   新增B2词汇: 66
#   当前覆盖率: 10.8%
#   选择: aqhdu-探索古希腊｜大英百科
#   新增B2词汇: 47
#   当前覆盖率: 14.2%
# 完成 B2 后累积覆盖率:
#   A1: 68.7%
#   A2: 81.6%
#   B1: 81.6%
#   B2: 68.3%
#   C1: 37.2%
#
# === 选择 C1 等级书籍 ===
#   C1等级候选书籍: 73本
# 目标词汇: 1300, 已覆盖: 484, 待覆盖: 816
#   选择: dxani-神圣罗马帝国｜大英百科
#   新增C1词汇: 62
#   当前覆盖率: 4.8%
#   选择: alkxn-计算机技术的演变｜大英百科
#   新增C1词汇: 41
#   当前覆盖率: 7.9%
#   选择: ywfuc-物理学｜大英百科
#   新增C1词汇: 39
#   当前覆盖率: 10.9%
# 完成 C1 后累积覆盖率:
#   A1: 69.9%
#   A2: 83.5%
#   B1: 84.2%
#   B2: 74.8%
#   C1: 48.2%
#
# ==================================================
# 📚 保守路径阅读路径
# ==================================================
# 总书籍数: 8
# 各等级分布: {'A1': 4, 'A2': 4, 'B1': 0, 'B2': 0, 'C1': 0}
#
# 📈 学习等级覆盖率:
#   A1: 443/801 (55.3%)
#   A2: 294/733 (40.1%)
#   B1: 166/800 (20.8%)
#   B2: 116/1358 (8.5%)
#   C1: 30/1300 (2.3%)
#   BEYOND: N/A (非学习目标，仅供参考)
#
# 📖 推荐阅读顺序:
#
#   === A1 等级 ===
#    1. lorkq-小公主 | 有声书虫（1级）
#       目标词汇: 198, 超纲词: 20, 难度: 1.9
#    2. btsbyz-爱情与金钱 | 有声书虫（1级）
#       目标词汇: 194, 超纲词: 8, 难度: 1.6
#    3. jvvhu-风中奇缘 | 有声书虫（2级）
#       目标词汇: 171, 超纲词: 14, 难度: 1.8
#    4. bbagn-潘德尔的巫师 | 有声书虫（1级）
#       目标词汇: 167, 超纲词: 15, 难度: 1.8
#
#   === A2 等级 ===
#    5. bbvlrq-弗兰肯斯坦 | 有声书虫（3级）
#       目标词汇: 157, 超纲词: 37, 难度: 2.2
#    6. dlmqa-华特·迪士尼传｜大英百科
#       目标词汇: 80, 超纲词: 21, 难度: 2.2
#    7. bvdvdp-乔布斯传｜大英百科
#       目标词汇: 73, 超纲词: 29, 难度: 2.3
#    8. cktrg-勃朗特一家的故事 | 有声书虫（3级）
#       目标词汇: 141, 超纲词: 57, 难度: 2.2
#
# ==================================================
# 📚 标准路径阅读路径
# ==================================================
# 总书籍数: 13
# 各等级分布: {'A1': 3, 'A2': 3, 'B1': 4, 'B2': 3, 'C1': 0}
#
# 📈 学习等级覆盖率:
#   A1: 520/801 (64.9%)
#   A2: 464/733 (63.3%)
#   B1: 410/800 (51.2%)
#   B2: 308/1358 (22.7%)
#   C1: 92/1300 (7.1%)
#   BEYOND: N/A (非学习目标，仅供参考)
#
# 📖 推荐阅读顺序:
#
#   === A1 等级 ===
#    1. xodqi-三怪客泛舟记 | 有声书虫（4级）
#       目标词汇: 329, 超纲词: 88, 难度: 2.4
#    2. bvdvdp-乔布斯传｜大英百科
#       目标词汇: 160, 超纲词: 29, 难度: 2.3
#    3. cktrg-勃朗特一家的故事 | 有声书虫（3级）
#       目标词汇: 283, 超纲词: 57, 难度: 2.2
#
#   === A2 等级 ===
#    4. asyse-远大前程 | 有声书虫（5级）
#       目标词汇: 297, 超纲词: 180, 难度: 2.8
#    5. bsvzaa-三十九级台阶 | 有声书虫（4级）
#       目标词汇: 254, 超纲词: 122, 难度: 2.5
#    6. bbzpii-格列佛游记 | 有声书虫（4级）
#       目标词汇: 257, 超纲词: 114, 难度: 2.6
